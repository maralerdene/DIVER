# %% [markdown]
# <a href="https://colab.research.google.com/github/maralerdene/DIVER/blob/main/PaperFoldingProblem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [Problem 1] Implementation using exponentiation arithmetic operators

# %%
THICKNESS = 0.00008

folded_thickness = THICKNESS * (2 **43)

print("Thickness: {} meters".format(folded_thickness))
# Out:
# Thickness: 703687441.77664 meters

# %% [markdown]
# [Problem 2] Unit conversion

# %%
# Convert meters to kilometers and display with two decimal places
print("Thickness: {: .2f} kilometers".format(folded_thickness / 1000))
# Out:
# Thickness:  703687.44 kilometers

# %% [markdown]
# [Problem 3] Created using a for statement

# %%
l = 2;
for i in range(42):
  l *= 2;

print("Thickness: {: .2f} kilometers".format(l*THICKNESS / 1000))
# Out:
# Thickness:  703687.44 kilometers

# %% [markdown]
# [Problem 4] Comparison of calculation time

# %%
# %%timeit
import time
start = time.time()
#####
# Paste the code you want to compare here
l = 2;
for i in range(42):
  l *= 2;

#print("Thickness: {: .2f} kilometers".format(l*THICKNESS / 1000)) 
#####
elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time))
# Out:
# Streaming output truncated to the last 5000 lines.
# time : 6.4373016357421875e-06[s]
# time : 5.9604644775390625e-06[s]
# time : 6.198883056640625e-06[s]
# time : 6.198883056640625e-06[s]
# time : 6.4373016357421875e-06[s]
# time : 6.198883056640625e-06[s]
# time : 6.4373016357421875e-06[s]
# time : 5.9604644775390625e-06[s]
# time : 5.9604644775390625e-06[s]
# time : 1.1682510375976562e-05[s]
# time : 6.198883056640625e-06[s]
# time : 5.7220458984375e-06[s]
# time : 6.198883056640625e-06[s]
# time : 1.1920928955078125e-05[s]
# time : 6.9141387939453125e-06[s]
# time : 1.0013580322265625e-05[s]
# time : 7.152557373046875e-06[s]
# time : 6.4373016357421875e-06[s]
# time : 5.9604644775390625e-06[s]
# time : 1.4781951904296875e-05[s]
# time : 6.4373016357421875e-06[s]
# time : 6.4373016357421875e-06[s]
# time : 5.9604644775390625e-06[s]
# time : 6.4373016357421875e-06[s]
# time : 6.198883056640625e-06[s]
# time : 6.4373016357421875e-06[s]
# time : 6.198883056640625e-06[s]
# ...

# %%
# %%timeit
import time
start = time.time()
#####
# Paste the code you want to compare here
folded_thickness = THICKNESS * (2 **43)

#print("Thickness: {: .2f} kilometers".format(l*THICKNESS / 1000)) 
#####
elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time))
# Out:
# Streaming output truncated to the last 5000 lines.
# time : 1.1920928955078125e-06[s]
# time : 4.76837158203125e-07[s]
# time : 4.76837158203125e-07[s]
# time : 1.430511474609375e-06[s]
# time : 4.76837158203125e-07[s]
# time : 4.76837158203125e-07[s]
# time : 9.5367431640625e-07[s]
# time : 4.76837158203125e-07[s]
# time : 4.76837158203125e-07[s]
# time : 9.5367431640625e-07[s]
# time : 4.76837158203125e-07[s]
# time : 4.76837158203125e-07[s]
# time : 4.76837158203125e-07[s]
# time : 4.76837158203125e-07[s]
# time : 4.76837158203125e-07[s]
# time : 4.76837158203125e-07[s]
# time : 4.76837158203125e-07[s]
# time : 4.76837158203125e-07[s]
# time : 4.76837158203125e-07[s]
# time : 4.76837158203125e-07[s]
# time : 4.76837158203125e-07[s]
# time : 4.76837158203125e-07[s]
# time : 7.152557373046875e-07[s]
# time : 4.76837158203125e-07[s]
# time : 4.291534423828125e-06[s]
# time : 7.152557373046875e-07[s]
# time : 4.76837158203125e-07[s]
# time : 7.152557373046875e-07[s]
# ...

# %% [markdown]
# [Problem 5] Saving to list

# %%
l = 2*THICKNESS;
array = [l]
for i in range(42):
  l *= 2;
  array.append(l)

# %% [markdown]
# [Problem 6] Displaying a line graph

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Display the graph. Title and axis label name.
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(array)  # Enter the variable name of the list in "List name"
plt.show()

# %% [markdown]
# [Problem 7] Graph customization

# %%
# Display a red line graph.
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(array, color='red')
plt.show()

# %%
# Display the axis value in large size.
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[m]")
plt.tick_params(labelsize=20) # Make settings related to axis values
plt.plot(array)
plt.show()
