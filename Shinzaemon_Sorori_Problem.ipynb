# %% [markdown]
# <a href="https://colab.research.google.com/github/maralerdene/DIVER/blob/main/Shinzaemon_Sorori_Problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [Problem 1] Number of rice grains on the 100th day

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def compute_sorori_shinzaemon():
    n_days=100
    n = 1
    list_n_grains = [1]
        
    list_total_grains = [1]
    sum = 1
    for i in range(n_days):
      n = n * 2
      sum = sum + n
      list_n_grains.append(n)
      list_total_grains.append(sum)
    # Display the graph. Title and axis label name.
    plt.title("the number of rice received on that day")
    plt.xlabel("number of days")
    plt.ylabel("number of rice received that day")
    plt.plot(list_n_grains)  # Enter the variable name of the list in "List name"
    plt.show()

    plt.title("the total number of rice received by that day")
    plt.xlabel("number of days")
    plt.ylabel("total number of rice received that day")
    plt.plot(list_total_grains)  # Enter the variable name of the list in "List name"
    plt.show()
    #print(list_total_grains)    

compute_sorori_shinzaemon()

# %% [markdown]
# [Problem 2] Number of rice grains other than the 100th day

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def compute_sorori_shinzaemon(n_days=100):
 
    n = 1
    list_n_grains = [1]
        
    list_total_grains = [1]
    sum = 1
    for i in range(n_days):
      n = n * 2
      sum = sum + n
      list_n_grains.append(n)
      list_total_grains.append(sum)
    #print(list_total_grains)    
          # Display the graph. Title and axis label name.
    plt.title("the number of rice received on that day")
    plt.xlabel("number of days")
    plt.ylabel("number of rice received that day")
    plt.plot(list_n_grains)  # Enter the variable name of the list in "List name"
    plt.show()

    plt.title("the total number of rice received by that day")
    plt.xlabel("number of days")
    plt.ylabel("total number of rice received that day")
    plt.plot(list_total_grains)  # Enter the variable name of the list in "List name"
    plt.show()
    return list_n_grains, list_total_grains


list_n_grains, list_total_grains = compute_sorori_shinzaemon(10)

# %% [markdown]
# [Problem 3] How many people can live for how many days with the rice they receive

# %%
def calculate_how_many_people_can_live(total_grain_count, count_people):
 
    return total_grain_count / (count_people * 1000)
    #print(list_total_grains)    

calculate_how_many_people_can_live(5000, 10)
# Out:
# 0.5
